# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("student_info.csv")
df
# Out:
#      Name  class1  class2   class3   New_Predication
# 0       a      19       98       28            48.33
# 1       b      18        1       28            15.67
# 2       c      10       57       46            37.67
# 3       d      52        3       46            33.67
# 4       e      50       22        5            25.67
# ...   ...     ...      ...      ...              ...
# 1206    h      74       57       40            57.00
# 1207    i      17        2        9             9.33
# 1208    g      17       19       72            36.00
# 1209    k      25        6       61            30.67
# 1210    a      51        6      100            52.33
#
# [1211 rows x 5 columns]

# %%
df.head()
# Out:
#   Name  class1  class2   class3   New_Predication
# 0    a      19       98       28            48.33
# 1    b      18        1       28            15.67
# 2    c      10       57       46            37.67
# 3    d      52        3       46            33.67
# 4    e      50       22        5            25.67

# %%
df.tail()
# Out:
#      Name  class1  class2   class3   New_Predication
# 1206    h      74       57       40            57.00
# 1207    i      17        2        9             9.33
# 1208    g      17       19       72            36.00
# 1209    k      25        6       61            30.67
# 1210    a      51        6      100            52.33

# %%
df.shape
# Out:
# (1211, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1211 entries, 0 to 1210
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             1211 non-null   object
#  1   class1           1211 non-null   int64
#  2   class2           1211 non-null   int64
#  3   class3           1211 non-null   int64
#  4   New_Predication  1211 non-null   float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 47.4+ KB

# %%
df.describe()
# Out:
#             class1      class2       class3   New_Predication
# count  1211.000000  1211.000000  1211.000000      1211.000000
# mean     48.965318    49.638315    51.648225        50.084021
# std      29.037999    28.729309    28.184459        16.557880
# min       1.000000     1.000000     1.000000         8.670000
# 25%      23.000000    25.000000    27.500000        38.670000
# 50%      48.000000    49.000000    52.000000        50.000000
# 75%      73.000000    74.000000    75.500000        61.000000
# max     100.000000   100.000000   100.000000        96.330000

# %%
df.isnull()
# Out:
#        Name  class1  class2   class3   New_Predication
# 0     False   False    False    False            False
# 1     False   False    False    False            False
# 2     False   False    False    False            False
# 3     False   False    False    False            False
# 4     False   False    False    False            False
# ...     ...     ...      ...      ...              ...
# 1206  False   False    False    False            False
# 1207  False   False    False    False            False
# 1208  False   False    False    False            False
# 1209  False   False    False    False            False
# 1210  False   False    False    False            False
#
# [1211 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Name               0
# class1             0
# class2             0
# class3             0
# New_Predication    0
# dtype: int64

# %%
df.mean()
# Out:
# <ipython-input-171-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# class1             48.965318
# class2             49.638315
# class3             51.648225
# New_Predication    50.084021
# dtype: float64

# %%
df2=df.fillna(df.mean())
# Out:
# <ipython-input-172-abccc728ec0d>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2=df.fillna(df.mean())

# %%
df2.isnull().sum()
# Out:
# Name               0
# class1             0
# class2             0
# class3             0
# New_Predication    0
# dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.barplot(x="Name",y="New_Predication",data=df2)
plt.show()

# %%
X=df2.drop(["Name","New_Predication"],axis="columns")
y=df2.drop(["Name","class1","class2 ","class3 "],axis="columns")

# %%
print("shape of X =",X.shape)
print("shape of y =",y.shape)
print (X)
# Out:
# shape of X = (1211, 3)
# shape of y = (1211, 1)
#       class1  class2   class3
# 0         19       98       28
# 1         18        1       28
# 2         10       57       46
# 3         52        3       46
# 4         50       22        5
# ...      ...      ...      ...
# 1206      74       57       40
# 1207      17        2        9
# 1208      17       19       72
# 1209      25        6       61
# 1210      51        6      100
#
# [1211 rows x 3 columns]

# %%
print (y)
# Out:
#       New_Predication
# 0               48.33
# 1               15.67
# 2               37.67
# 3               33.67
# 4               25.67
# ...               ...
# 1206            57.00
# 1207             9.33
# 1208            36.00
# 1209            30.67
# 1210            52.33
#
# [1211 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2,random_state=51) # taking 20% data for test. 20% is randomly
print("shape of X_train =",X_train.shape)
print("shape of y_train =",y_train.shape)
print("shape of X_test =",X_test.shape)
print("shape of y_test =",y_test.shape)
# Out:
# shape of X_train = (968, 3)
# shape of y_train = (968, 1)
# shape of X_test = (243, 3)
# shape of y_test = (243, 1)

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([[0.33332842, 0.33332974, 0.33333036]])

# %%
lr.intercept_
# Out:
# array([0.00065428])

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([[33.00024854],
#        [67.66659252],
#        [66.99991322],
#        [55.66668127],
#        [42.3335447 ],
#        [74.99977882],
#        [48.33343464],
#        [42.33346641],
#        [23.33373375],
#        [37.66693631],
#        [33.33361964],
#        [32.00035178],
#        [41.66684487],
#        [38.0002137 ],
#        [23.66705617],
#        [58.99997498],
#        [53.66662674],
#        [44.00014017],
#        [72.33314662],
#        [79.99977703],
#        [42.66677289],
#        [47.33345049],
#        [46.66673885],
#        [25.33366639],
#        [52.66677402],
#        [24.66707782],
#        [47.00019718],
#        [54.33331217],
#        [31.66698043],
#        [58.66667414],
#        [46.33344263],
#        [47.66672592],
#        [68.66660583],
#        [76.66643731],
#        [18.33379139],
#        [49.66671065],
#        [69.66645729],
#        [57.6666049 ],
#        [42.66684355],
#        [74.33309218],
#        [53.33334352],
#        [39.000253  ],
#        [61.66661501],
#        [47.00009261],
#        [58.66667323],
#        [51.00012997],
#        [40.00023834],
#        [77.6664253 ],
#        [66.33316791],
#        [56.66670583],
#        [39.66690326],
#        [49.66677312],
#        [32.66691983],
#        [34.33359633],
#        [28.33364857],
#        [32.66688543],
#        [47.33346324],
#        [54.33344639],
#        [23.00037841],
#        [62.99998565],
#        [37.3335232 ],
#        [58.33338652],
#        [69.99987901],
#        [41.3334724 ],
#        [59.00000732],
#        [26.66703365],
#        [31.0002858 ],
#        [62.33324553],
#        [67.66652149],
#        [55.9999956 ],
#        [66.99984416],
#        [52.66668118],
#        [43.33352112],
#        [65.99992959],
#        [16.00046139],
#        [65.33325044],
#        [45.33349298],
#        [23.66699419],
#        [74.333135  ],
#        [33.66698858],
#        [31.00034353],
#        [48.33346822],
#        [93.99958324],
#        [68.33315098],
#        [38.66694038],
#        [50.00012947],
#        [37.3336092 ],
#        [44.33350358],
#        [57.66661229],
#        [30.66698644],
#        [42.00007796],
#        [29.00036153],
#        [89.99960663],
#        [78.66645469],
#        [43.00020895],
#        [68.33318785],
#        [45.33350301],
#        [21.33377615],
#        [48.00016399],
#        [24.66699409],
#        [60.99992455],
#        [42.33352769],
#        [53.00010577],
#        [31.33366407],
#        [42.00019775],
#        [71.33310133],
#        [49.66670869],
#        [40.66692456],
#        [50.00013119],
#        [57.66667249],
#        [35.66697084],
#        [77.3331029 ],
#        [20.66710571],
#        [36.6669106 ],
#        [52.66674642],
#        [68.66650938],
#        [56.6666076 ],
#        [92.66624873],
#        [54.00004406],
#        [22.00043181],
#        [44.33346585],
#        [71.99984269],
#        [54.0000769 ],
#        [41.33349762],
#        [86.33300224],
#        [40.66692667],
#        [75.6664449 ],
#        [53.33343616],
#        [19.66711531],
#        [72.66649097],
#        [55.33330328],
#        [41.0002176 ],
#        [70.9998483 ],
#        [52.33335231],
#        [55.00005338],
#        [31.33358252],
#        [26.33372893],
#        [54.00011005],
#        [66.9998992 ],
#        [59.33331785],
#        [51.00013184],
#        [44.33350591],
#        [54.00010476],
#        [63.66651052],
#        [36.66690883],
#        [33.66699447],
#        [64.33330035],
#        [88.99962404],
#        [83.33301256],
#        [61.66659191],
#        [63.66664035],
#        [44.33350337],
#        [41.00024149],
#        [54.66677402],
#        [38.33356115],
#        [38.3335649 ],
#        [43.00010295],
#        [48.66677653],
#        [46.33352395],
#        [87.99966914],
#        [72.33311197],
#        [55.33342399],
#        [36.33353583],
#        [46.66673084],
#        [65.99990329],
#        [65.99983014],
#        [50.00006986],
#        [57.66665539],
#        [77.33315514],
#        [ 9.33387834],
#        [19.0004317 ],
#        [34.66685682],
#        [64.999927  ],
#        [59.3333313 ],
#        [64.99991178],
#        [60.99990478],
#        [57.99992871],
#        [43.00020179],
#        [54.33333283],
#        [60.99988185],
#        [32.00027377],
#        [52.00002188],
#        [38.00024573],
#        [53.33342503],
#        [17.66709633],
#        [55.66673844],
#        [74.99980226],
#        [49.33334389],
#        [60.33326453],
#        [32.66702329],
#        [29.66700206],
#        [41.33352849],
#        [46.33339299],
#        [59.66660114],
#        [31.00028091],
#        [22.00041943],
#        [38.66690551],
#        [53.00005449],
#        [45.00013301],
#        [58.99993053],
#        [67.33318846],
#        [63.99990684],
#        [42.00021302],
#        [29.66693479],
#        [62.33331115],
#        [63.66656868],
#        [76.99977294],
#        [52.3334705 ],
#        [54.00005173],
#        [61.66657306],
#        [35.00030111],
#        [69.66654944],
#        [53.99996291],
#        [58.99991439],
#        [23.33371893],
#        [31.00031802],
#        [26.00039308],
#        [79.6664139 ],
#        [36.00021527],
#        [55.33331877],
#        [33.33364934],
#        [45.00008006],
#        [77.66639281],
#        [19.66708749],
#        [49.00011767],
#        [56.33332406],
#        [55.00007516],
#        [31.00033021],
#        [53.00002036],
#        [45.00013663],
#        [64.66650046],
#        [34.00030374],
#        [71.66650278],
#        [56.66663315],
#        [58.33326863],
#        [33.33358377],
#        [75.33307786],
#        [95.332891  ],
#        [50.66677676],
#        [48.66674914],
#        [50.33348041],
#        [42.00014252],
#        [52.33339313]])

# %%
lr.score(X_test,y_test)
# Out:
# 0.9999999745318663

# %%
import joblib
joblib.dump(lr, "Student_mark_prediction_model.pkl")
# Out:
# ['Student_mark_prediction_model.pkl']

# %%
model = joblib.load("Student_mark_prediction_model.pkl")

# %%
model.predict([[10,95,80]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[61.66669296]])
